# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
x = pd.Series(range(10, 20))

y = pd.Series([2, 1, 4, 5, 8, 12, 18, 25, 96, 48])

z = pd.Series([5, 3, 2, 1, 0, -2, -8, -11, -15, -16])

# %%
x.corr(y)
# Out:
# 0.7586402890911867

# %%
xy = pd.DataFrame({'x-values': x, 'y-values': y})

xy.corr()
# Out:
#           x-values  y-values
# x-values   1.00000   0.75864
# y-values   0.75864   1.00000

# %%
# Change the size of the subplots
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(12, 4))

# plot the data
axes[0].scatter(x, y)
# fits the best fitting line to the data
axes[0].plot(x,np.poly1d(np.polyfit(x, y, 1))(x), color='red')
#title
axes[0].set_title('X vs Y')


# plot the data
axes[1].scatter(x, z)
# fits the best fitting line to the data
axes[1].plot(x ,np.poly1d(np.polyfit(x, z, 1))(x), color='red')
#title
axes[1].set_title('X vs Z')

# plot the data
axes[2].scatter(y, z)
# fits the best fitting line to the data
axes[2].plot(y,np.poly1d(np.polyfit(y, z, 1))(y), color='red')
#title
axes[2].set_title('Y vs Z')

plt.tight_layout()
plt.show()

# %%
xyz = pd.DataFrame({'x-values': x, 'y-values': y, 'z-values':z})

xyz.corr()
# Out:
#           x-values  y-values  z-values
# x-values  1.000000  0.758640 -0.968072
# y-values  0.758640  1.000000 -0.834079
# z-values -0.968072 -0.834079  1.000000

# %% [markdown]
#    # Wrapper Feature Selection

# %%
from sklearn import datasets

boston = datasets.load_boston()

bos = pd.DataFrame(boston.data, columns = boston.feature_names)

bos['Price'] = boston.target

bos.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  Price
# 0     15.3  396.90   4.98   24.0
# 1     17.8  396.90   9.14   21.6
# 2     17.8  392.83   4.03   34.7
# 3     18.7  394.63   2.94   33.4
# 4     18.7  396.90   5.33   36.2

# %%
bos.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'Price'],
#       dtype='object')

# %%
bos.shape
# Out:
# (506, 14)

# %%
# bos.isnull().sum()

# %%
# bos.duplicated().sum()

# %%
# bos.dtypes

# %%
X = bos.drop("Price", axis=1)       # feature matrix
y = bos['Price']               # target feature

# %%
#importing the necessary libraries

! pip install mlxtend

from mlxtend.feature_selection import SequentialFeatureSelector as SFS

from sklearn.linear_model import LinearRegression
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: mlxtend in c:\users\lenovo\appdata\roaming\python\python39\site-packages (0.21.0)
# Requirement already satisfied: matplotlib>=3.0.0 in e:\anaconda\lib\site-packages (from mlxtend) (3.5.2)
# Requirement already satisfied: numpy>=1.16.2 in e:\anaconda\lib\site-packages (from mlxtend) (1.21.5)
# Requirement already satisfied: scipy>=1.2.1 in e:\anaconda\lib\site-packages (from mlxtend) (1.9.1)
# Requirement already satisfied: setuptools in e:\anaconda\lib\site-packages (from mlxtend) (63.4.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in e:\anaconda\lib\site-packages (from mlxtend) (1.0.2)
# Requirement already satisfied: pandas>=0.24.2 in e:\anaconda\lib\site-packages (from mlxtend) (1.4.4)
# Requirement already satisfied: joblib>=0.13.2 in e:\anaconda\lib\site-packages (from mlxtend) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in e:\anaconda\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in e:\anaconda\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in e:\anaconda\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.7 in e:\anaconda\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in e:\anaconda\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in e:\anaconda\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (9.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in e:\anaconda\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.25.0)
# Requirement already satisfied: pytz>=2020.1 in e:\anaconda\lib\site-packages (from pandas>=0.24.2->mlxtend) (2022.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in e:\anaconda\lib\site-packages (from scikit-learn>=1.0.2->mlxtend) (2.2.0)
# Requirement already satisfied: six>=1.5 in e:\anaconda\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)

# %%
# Sequential Forward Selection(sfs)
sfs = SFS(LinearRegression(),
          k_features=3,
          forward=True,
          floating=False,
          scoring = 'r2',
          cv = 0)

sfs.fit(X, y)

sfs.k_feature_names_
# Out:
# ('RM', 'PTRATIO', 'LSTAT')

# %%
sfs1 = SFS(LinearRegression(),
         k_features=(3,11),
         forward=True,
         floating=False,
         cv=0)
sfs1.fit(X, y)

from mlxtend.plotting import plot_sequential_feature_selection as plot_sfs
import matplotlib.pyplot as plt

fig1 = plot_sfs(sfs1.get_metric_dict(), kind='std_dev')
plt.title('Sequential Forward Selection (w. StdErr)')
plt.grid()
plt.show()

# %%
#Sequential backward selection(sbs)
sbs = SFS(LinearRegression(),
         k_features=5,
         forward=False,
         floating=False,
         cv=0)
sbs.fit(X, y)
sbs.k_feature_names_
# Out:
# ('NOX', 'RM', 'DIS', 'PTRATIO', 'LSTAT')

# %%
# Sequential Forward Floating Selection(sffs)
sffs = SFS(LinearRegression(),
         k_features=(3,11),
         forward=True,
         floating=True,       ##(floating--> mix ben el forward w el backward)
         cv=0)
sffs.fit(X, y)
sffs.k_feature_names_

fig1 = plot_sfs(sffs.get_metric_dict(), kind='std_dev')
plt.title('Sequential Forward Selection (w. StdErr)')
plt.grid()
plt.show()

# %%
# sklearn library

from sklearn.feature_selection import SequentialFeatureSelector

# %%
sfs = SequentialFeatureSelector(LinearRegression(), n_features_to_select=3)
sfs.fit(X, y)
# Out:
# SequentialFeatureSelector(estimator=LinearRegression(), n_features_to_select=3)

# %%
sfs.get_feature_names_out(X.columns)
# Out:
# array(['CHAS', 'PTRATIO', 'LSTAT'], dtype=object)

# %%
new_features= pd.DataFrame(sfs.transform(X), columns= sfs.get_feature_names_out(X.columns))

new_features.head()
# Out:
#    CHAS  PTRATIO  LSTAT
# 0   0.0     15.3   4.98
# 1   0.0     17.8   9.14
# 2   0.0     17.8   4.03
# 3   0.0     18.7   2.94
# 4   0.0     18.7   5.33

# %% [raw]
# heat correlation matrix for boston dataset

# %%
from sklearn.feature_selection import SelectKBest,chi2,f_classif

# %%
features=SelectKBest(score_func=f_classif,k=7)

# %%
selected_features=features.fit_transform(X,y)

# %%
selected_features.shape
# Out:
# (506, 7)

# %%
X
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# 3       18.7  394.63   2.94
# 4       18.7  396.90   5.33
# ..       ...     ...    ...
# 501     21.0  391.99   9.67
# 502     21.0  396.90   9.08
# 503     21.0  396.90   5.64
# 504     21.0  393.45   6.48
# 505     21.0  396.90   7.88
#
# [506 rows x 13 columns]

# %%
X.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# B       -0.385064  0.175520 -0.356977  0.048788 -0.380051  0.128069 -0.273534
# LSTAT    0.455621 -0.412995  0.603800 -0.053929  0.590879 -0.613808  0.602339
#
#               DIS       RAD       TAX   PTRATIO         B     LSTAT
# CRIM    -0.379670  0.625505  0.582764  0.289946 -0.385064  0.455621
# ZN       0.664408 -0.311948 -0.314563 -0.391679  0.175520 -0.412995
# INDUS   -0.708027  0.595129  0.720760  0.383248 -0.356977  0.603800
# CHAS    -0.099176 -0.007368 -0.035587 -0.121515  0.048788 -0.053929
# NOX     -0.769230  0.611441  0.668023  0.188933 -0.380051  0.590879
# RM       0.205246 -0.209847 -0.292048 -0.355501  0.128069 -0.613808
# AGE     -0.747881  0.456022  0.506456  0.261515 -0.273534  0.602339
# DIS      1.000000 -0.494588 -0.534432 -0.232471  0.291512 -0.496996
# RAD     -0.494588  1.000000  0.910228  0.464741 -0.444413  0.488676
# TAX     -0.534432  0.910228  1.000000  0.460853 -0.441808  0.543993
# PTRATIO -0.232471  0.464741  0.460853  1.000000 -0.177383  0.374044
# B        0.291512 -0.444413 -0.441808 -0.177383  1.000000 -0.366087
# LSTAT   -0.496996  0.488676  0.543993  0.374044 -0.366087  1.000000
